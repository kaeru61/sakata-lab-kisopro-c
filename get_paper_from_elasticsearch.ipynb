# %%
import pandas as pd
from elasticsearch import helpers
from elasticsearch import Elasticsearch
es = Elasticsearch(
    "http://133.11.72.200:9200/",
    # ca_certs="./ti06.crt",
    timeout=500,
    basic_auth=('oa_reader', 'five@godtruth')
)

def build_es_query_titleabstract_or(keywords,gte=1800,lte=2030):
    """Build Elasticsearch query for a specific keyword."""

    list_keywords = []
    for key in keywords:
        list_keywords = list_keywords + [  {
                        "match_phrase": {
                          "abstract": key
                        }
                      },
                                      {
                        "match_phrase": {
                          "title": key
                        }
                      }]
    
    return {
          "query": {
            "bool": {
              "must": [
                {
                  "range": {
                    "publication_year": {
                      "gte": gte,   
                      "lte": lte   
                    }
                  }
                },
                { "range" : { "cited_by_count" :{
                        "gte" : 0,
                    } }},   
                {
                  "bool": {
                    "should": list_keywords
                }
                }
              ]
            }
          }
        }
    

def build_es_query_topic(x):
    """Build Elasticsearch query for a topic."""
    topics = pd.read_pickle('/disks/qnap3/shared/openalex-24/data/master/topics.pickle')
    if x in topics.index:
        keyword = topics.loc[x].display_name
    else:
        keyword = topics.loc["https://openalex.org/"+str(x)].display_name
        
    return {
        "query": {
            "bool": {
            "must" : [
                { "match" : { "language" : "en" }},
                { "term" : { "topics": {"value":keyword} }}, 
                { "range" : { "cited_by_count" :{"gte" : 0,} }},       
                { "range" : { "publication_year" :{"gte" : 0,"lte":2025} }}
            ]

            }
        }
    }
def build_es_query_by_ids(id_list):
    return {
        "query": {
            "bool": {
                "must": [
                    {
                        "terms": {
                            "id": id_list
                        }
                    }
                ]
            }
        }
    }




def get_result(es_client, es_index, es_query, scroll_time="2m", batch_size=1000):
    all_hits = []
    response = es_client.search(index=es_index, body=es_query, scroll=scroll_time, size=batch_size)
    scroll_id = response['_scroll_id']
    
    while response['hits']['hits']:
        all_hits.extend(hit['_source'] for hit in response['hits']['hits'])
        response = es_client.scroll(scroll_id=scroll_id, scroll=scroll_time)
    
    es_client.clear_scroll(scroll_id=scroll_id)
    result = pd.DataFrame(all_hits)
    
    if 'cited_by_count' in result.columns:
        result = result.sort_values('cited_by_count')
    if 'id' in result.columns:
        result.index = result['id']
    
    journal = pd.read_pickle('/disks/qnap3/shared/openalex-24/data/journal/journal.pickle')
    result['journal'] = result['primary_location'].map(journal.get('display_name', {}))
    result['journal_if'] = result['primary_location'].map(journal.get('2yr_mean_citedness', {}))
    
    print(len(result))
    return result
# Out:
# /tmp/ipykernel_1449/1659818795.py:4: DeprecationWarning: The 'timeout' parameter is deprecated in favor of 'request_timeout'
#   es = Elasticsearch(

# %% [markdown]
# # TOPICの全論文を取得

# %%
#例えば、https://openalex.org/topics/T10020の全論文を取得するとき　
papers = get_result(es,'oa_papers',build_es_query_topic("T10020") )
print(len(papers))
papers.head()
# Out:
# /tmp/ipykernel_1449/1659818795.py:94: DeprecationWarning: Received 'size' via a specific parameter in the presence of a 'body' parameter, which is deprecated and will be removed in a future version. Instead, use only 'body' or only specific parameters.
#   response = es_client.search(index=es_index, body=es_query, scroll=scroll_time, size=batch_size)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 2
#       1 #例えば、https://openalex.org/topics/T10020の全論文を取得するとき
# ----> 2 papers = get_result(es,'oa_papers',build_es_query_topic("T10020") )
#       3 print(len(papers))
#       4 papers.head()
#
# Cell In[66], line 99, in get_result(es_client, es_index, es_query, scroll_time, batch_size)
#      97 while response['hits']['hits']:
#      98     all_hits.extend(hit['_source'] for hit in response['hits']['hits'])
# ---> 99     response = es_client.scroll(scroll_id=scroll_id, scroll=scroll_time)
#     101 es_client.clear_scroll(scroll_id=scroll_id)
#     102 result = pd.DataFrame(all_hits)
#
# File /usr/local/lib/python3.12/site-packages/elasticsearch/_sync/client/utils.py:455, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     452         except KeyError:
#     453             pass
# --> 455 return api(*args, **kwargs)
#
# File /usr/local/lib/python3.12/site-packages/elasticsearch/_sync/client/__init__.py:3733, in Elasticsearch.scroll(self, scroll_id, error_trace, filter_path, human, pretty, rest_total_hits_as_int, scroll, body)
#    3731 if __body is not None:
#    3732     __headers["content-type"] = "application/json"
# -> 3733 return self.perform_request(  # type: ignore[return-value]
#    3734     "POST",
#    3735     __path,
#    3736     params=__query,
#    3737     headers=__headers,
#    3738     body=__body,
#    3739     endpoint_id="scroll",
#    3740     path_parts=__path_parts,
#    3741 )
#
# File /usr/local/lib/python3.12/site-packages/elasticsearch/_sync/client/_base.py:271, in BaseClient.perform_request(self, method, path, params, headers, body, endpoint_id, path_parts)
#     255 def perform_request(
#     256     self,
#     257     method: str,
#    (...)    264     path_parts: Optional[Mapping[str, Any]] = None,
#     265 ) -> ApiResponse[Any]:
#     266     with self._otel.span(
#     267         method,
#     268         endpoint_id=endpoint_id,
#     269         path_parts=path_parts or {},
#     270     ) as otel_span:
# --> 271         response = self._perform_request(
#     272             method,
#     273             path,
#     274             params=params,
#     275             headers=headers,
#     276             body=body,
#     277             otel_span=otel_span,
#     278         )
#     279         otel_span.set_elastic_cloud_metadata(response.meta.headers)
#     280         return response
#
# File /usr/local/lib/python3.12/site-packages/elasticsearch/_sync/client/_base.py:316, in BaseClient._perform_request(self, method, path, params, headers, body, otel_span)
#     313 else:
#     314     target = path
# --> 316 meta, resp_body = self.transport.perform_request(
#     317     method,
#     318     target,
#     319     headers=request_headers,
#     320     body=body,
#     321     request_timeout=self._request_timeout,
#     322     max_retries=self._max_retries,
#     323     retry_on_status=self._retry_on_status,
#     324     retry_on_timeout=self._retry_on_timeout,
#     325     client_meta=self._client_meta,
#     326     otel_span=otel_span,
#     327 )
#     329 # HEAD with a 404 is returned as a normal response
#     330 # since this is used as an 'exists' functionality.
#     331 if not (method == "HEAD" and meta.status == 404) and (
#     332     not 200 <= meta.status < 299
#     333     and (
#    (...)    337     )
#     338 ):
#
# File /usr/local/lib/python3.12/site-packages/elastic_transport/_transport.py:342, in Transport.perform_request(self, method, target, body, headers, max_retries, retry_on_status, retry_on_timeout, request_timeout, client_meta, otel_span)
#     340 try:
#     341     otel_span.set_node_metadata(node.host, node.port, node.base_url, target)
# --> 342     resp = node.perform_request(
#     343         method,
#     344         target,
#     345         body=request_body,
#     346         headers=request_headers,
#     347         request_timeout=request_timeout,
#     348     )
#     349     _logger.info(
#     350         "%s %s%s [status:%s duration:%.3fs]"
#     351         % (
#    (...)    357         )
#     358     )
#     360     if method != "HEAD":
#
# File /usr/local/lib/python3.12/site-packages/elastic_transport/_node/_http_urllib3.py:167, in Urllib3HttpNode.perform_request(self, method, target, body, headers, request_timeout)
#     164 else:
#     165     body_to_send = None
# --> 167 response = self.pool.urlopen(
#     168     method,
#     169     target,
#     170     body=body_to_send,
#     171     retries=Retry(False),
#     172     headers=request_headers,
#     173     **kw,  # type: ignore[arg-type]
#     174 )
#     175 response_headers = HttpHeaders(response.headers)
#     176 data = response.data
#
# File /usr/local/lib/python3.12/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File /usr/local/lib/python3.12/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /usr/local/lib/python3.12/site-packages/urllib3/connection.py:530, in HTTPConnection.getresponse(self)
#     521     log.warning(
#     522         "Failed to parse headers (url=%s): %s",
#     523         _url_from_connection(self, resp_options.request_url),
#     524         hpe,
#     525         exc_info=True,
#     526     )
#     528 headers = HTTPHeaderDict(httplib_response.msg.items())
# --> 530 response = HTTPResponse(
#     531     body=httplib_response,
#     532     headers=headers,
#     533     status=httplib_response.status,
#     534     version=httplib_response.version,
#     535     version_string=getattr(self, "_http_vsn_str", "HTTP/?"),
#     536     reason=httplib_response.reason,
#     537     preload_content=resp_options.preload_content,
#     538     decode_content=resp_options.decode_content,
#     539     original_response=httplib_response,
#     540     enforce_content_length=resp_options.enforce_content_length,
#     541     request_method=resp_options.request_method,
#     542     request_url=resp_options.request_url,
#     543     sock_shutdown=_shutdown,
#     544 )
#     545 return response
#
# File /usr/local/lib/python3.12/site-packages/urllib3/response.py:639, in HTTPResponse.__init__(self, body, headers, status, version, version_string, reason, preload_content, decode_content, original_response, pool, connection, msg, retries, enforce_content_length, request_method, request_url, auto_close, sock_shutdown)
#     637 # If requested, preload the body.
#     638 if preload_content and not self._body:
# --> 639     self._body = self.read(decode_content=decode_content)
#
# File /usr/local/lib/python3.12/site-packages/urllib3/response.py:955, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     952     if len(self._decoded_buffer) >= amt:
#     953         return self._decoded_buffer.get(amt)
# --> 955 data = self._raw_read(amt)
#     957 flush_decoder = amt is None or (amt != 0 and not data)
#     959 if not data and len(self._decoded_buffer) == 0:
#
# File /usr/local/lib/python3.12/site-packages/urllib3/response.py:879, in HTTPResponse._raw_read(self, amt, read1)
#     876 fp_closed = getattr(self._fp, "closed", False)
#     878 with self._error_catcher():
# --> 879     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     880     if amt is not None and amt != 0 and not data:
#     881         # Platform-specific: Buggy versions of Python.
#     882         # Close the connection when no data is returned
#    (...)    887         # not properly close the connection in all cases. There is
#     888         # no harm in redundantly calling close.
#     889         self._fp.close()
#
# File /usr/local/lib/python3.12/site-packages/urllib3/response.py:862, in HTTPResponse._fp_read(self, amt, read1)
#     859     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     860 else:
#     861     # StringIO doesn't like amt=None
# --> 862     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /usr/local/lib/python3.12/http/client.py:473, in HTTPResponse.read(self, amt)
#     470     return b""
#     472 if self.chunked:
# --> 473     return self._read_chunked(amt)
#     475 if amt is not None and amt >= 0:
#     476     if self.length is not None and amt > self.length:
#     477         # clip the read to the "end of response"
#
# File /usr/local/lib/python3.12/http/client.py:603, in HTTPResponse._read_chunked(self, amt)
#     600     self.chunk_left = chunk_left - amt
#     601     break
# --> 603 value.append(self._safe_read(chunk_left))
#     604 if amt is not None:
#     605     amt -= chunk_left
#
# File /usr/local/lib/python3.12/http/client.py:642, in HTTPResponse._safe_read(self, amt)
#     635 def _safe_read(self, amt):
#     636     """Read the number of bytes requested.
#     637
#     638     This function should be used when <amt> bytes "should" be present for
#     639     reading. If the bytes are truly not available (due to EOF), then the
#     640     IncompleteRead exception can be used to detect the problem.
#     641     """
# --> 642     data = self.fp.read(amt)
#     643     if len(data) < amt:
#     644         raise IncompleteRead(data, amt-len(data))
#
# File /usr/local/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# # 特定のキーワードを含む論文を取得

# %%
#例えば、"large language models",'llms','llm'のいずれかの単語を含む、2024年から2024年までの全論文を取得するとき　
papers = get_result(es,'oa_papers',build_es_query_titleabstract_or(["large language models",'llms','llm'],2024,2024) )
print(len(papers))
papers.head()
# Out:
# /tmp/ipykernel_1449/4191710447.py:79: DeprecationWarning: Received 'size' via a specific parameter in the presence of a 'body' parameter, which is deprecated and will be removed in a future version. Instead, use only 'body' or only specific parameters.
#   response = es_client.search(index=es_index, body=es_query, scroll=scroll_time, size=batch_size)
# 31281
# 31281
#                                                        doi  \
# id
# 4403116255
# 4402111602  https://doi.org/10.21437/interspeech.2024-1700
# 4403964218       https://doi.org/10.48550/arxiv.2410.04834
# 4396821954       https://doi.org/10.48550/arxiv.2405.05329
# 4399205174       https://doi.org/10.1609/icwsm.v18i1.31446
#
#                                                        fields  \
# id
# 4403116255                    [Computer Science, Engineering]
# 4402111602   [Computer Science, Computer Science, Psychology]
# 4403964218                                      [Engineering]
# 4396821954  [Computer Science, Computer Science, Decision ...
# 4399205174                                 [Computer Science]
#
#                                                   affliations  \
# id
# 4403116255                                       [[], [], []]
# 4402111602                               [[], [], [], [], []]
# 4403964218                           [[], [], [], [], [], []]
# 4396821954                                       [[], [], []]
# 4399205174  [[138847295], [], [], [], [138847295], [138847...
#
#                                                 primary_topic  \
# id
# 4403116255     Visual Question Answering in Images and Videos
# 4402111602                      Speech Recognition Technology
# 4403964218  Iterative Learning Control in Engineering Prac...
# 4396821954                        Natural Language Processing
# 4399205174  Automated Detection of Hate Speech and Offensi...
#
#                                                   authorships  cited_by_count  \
# id
# 4403116255               [5036727505, 5101776086, 5109890544]               0
# 4402111602  [5092418416, 5113361537, 5091143209, 501238656...               0
# 4403964218  [5102006980, 5101808283, 5000871321, 510044172...               0
# 4396821954               [5080091586, 5056246621, 5113880378]               0
# 4399205174  [5001896240, 5027705731, 5094057195, 509895682...               0
#
#                                                      concepts  \
# id
# 4403116255  [Benchmark (surveying), Computer science, Arti...
# 4402111602  [Duration (music), Computer science, Speech re...
# 4403964218  [Simple (philosophy), Computer science, Contro...
# 4396821954  [Cache, Computer science, Key (lock), Scalabil...
# 4399205174  [Context (archaeology), Hessian matrix, Comput...
#
#                                                     subfields  \
# id
# 4403116255  [Computer Vision and Pattern Recognition, Cont...
# 4402111602  [Artificial Intelligence, Signal Processing, E...
# 4403964218                  [Control and Systems Engineering]
# 4396821954  [Artificial Intelligence, Artificial Intellige...
# 4399205174                          [Artificial Intelligence]
#
#             publication_date                  primary_location  ...  \
# id                                                              ...
# 4403116255          20241004  https://openalex.org/S4306400194  ...
# 4402111602          20240901                                    ...
# 4403964218          20241007  https://openalex.org/S4306400194  ...
# 4396821954          20240508  https://openalex.org/S4306400194  ...
# 4399205174          20240528  https://openalex.org/S4387284482  ...
#
#                                                      abstract  language  \
# id
# 4403116255  Generalizing language-conditioned robotic poli...        en
# 4402111602  Audio-visual alignment after dubbing is a chal...        en
# 4403964218  Direct Preference Optimization (DPO) has emerg...        en
# 4396821954  Large Language Model or LLM inference has two ...        en
# 4399205174  This study describes a dataset that allows to ...        en
#
#                                            text_embedding_256  \
# id
# 4403116255  [0.011329010128974915, 0.008168527856469154, 0...
# 4402111602  [-0.024551065638661385, 0.05350632965564728, 0...
# 4403964218  [0.0264631025493145, 0.009874476119875908, 0.1...
# 4396821954  [0.014008685015141964, -0.025452211499214172, ...
# 4399205174  [-0.00195204874034971, 0.041102878749370575, 0...
#
#                                topic_sub_clustering citedby  \
# id
# 4403116255  [llm_10002, T10653_40001, T11714_60001]     NaN
# 4402111602                                      NaN     NaN
# 4403964218                                      NaN     NaN
# 4396821954                                      NaN     NaN
# 4399205174                [llm_50003, T12262_20001]     NaN
#
#                                                     reference cited_by_year  \
# id
# 4403116255                                                NaN           NaN
# 4402111602                                                NaN           NaN
# 4403964218                                                NaN           NaN
# 4396821954                                                NaN           NaN
# 4399205174  [2099865247, 2302501749, 2912924812, 294757159...          None
#
#            new_score                                            journal  \
# id
# 4403116255       NaN                         arXiv (Cornell University)
# 4402111602       NaN                                                NaN
# 4403964218       NaN                         arXiv (Cornell University)
# 4396821954       NaN                         arXiv (Cornell University)
# 4399205174       NaN  Proceedings of the International AAAI Conferen...
#
#            journal_if
# id
# 4403116255   0.632485
# 4402111602        NaN
# 4403964218   0.632485
# 4396821954   0.632485
# 4399205174   2.546843
#
# [5 rows x 27 columns]

# %%
#例えば、"large language models",'llms','llm'のいずれかの単語を含む、2024年から2024年までの全論文を取得するとき　
papers = get_result(es,'oa_papers',build_es_query_titleabstract_or(["sports analytics",'sports data science','sports performance analysis','machine learning in sports','sports statistics'],2024,2024) )
print(len(papers))
papers.head()
# Out:
# /tmp/ipykernel_1449/1659818795.py:94: DeprecationWarning: Received 'size' via a specific parameter in the presence of a 'body' parameter, which is deprecated and will be removed in a future version. Instead, use only 'body' or only specific parameters.
#   response = es_client.search(index=es_index, body=es_query, scroll=scroll_time, size=batch_size)
# 182
# 182
#                                                      abstract  \
# id
# 4394566173  To explore the prospects and challenges of app...
# 4396610510  Abstract: Due to the lack of review papers pub...
# 4392144307  This MLSA 2023 proceedings deals with machine ...
# 4391092065  More and more sports teams are looking to util...
# 4391618811  More and more sports teams are looking to util...
#
#                                                         title  \
# id
# 4394566173  THE PROGRESS IN THE RESEARCH OF MACHINE LEARNI...
# 4396610510                       A Review of Sports Analytics
# 4392144307  Machine Learning and Data Mining for Sports An...
# 4391092065  IMPLEMENTATION OF THE MASTER'S PROGRAM IN SPOR...
# 4391618811  IMPLEMENTATION OF THE MASTER'S PROGRAM IN SPOR...
#
#                                                      concepts          id  \
# id
# 4394566173  [Sports medicine, Computer science, Psychology...  4394566173
# 4396610510        [Analytics, Computer science, Data science]  4396610510
# 4392144307  [Basketball, Analytics, Football, Racket, Comp...  4392144307
# 4391092065  [Analytics, Computer science, Field (mathemati...  4391092065
# 4391618811  [Analytics, Computer science, Field (mathemati...  4391618811
#
#                                                        fields  \
# id
# 4394566173                     [Health Professions, Medicine]
# 4396610510              [Business, Management and Accounting]
# 4392144307  [Business, Management and Accounting, Computer...
# 4391092065  [Health Professions, Business, Management and ...
# 4391618811  [Health Professions, Business, Management and ...
#
#                             primary_location  is_oa  cited_by_count  \
# id
# 4394566173  https://openalex.org/S4210172178   True               0
# 4396610510  https://openalex.org/S2764566388   True               0
# 4392144307  https://openalex.org/S2764900261   True               0
# 4391092065                                     True               0
# 4391618811                                     True               0
#
#                                                        topics  \
# id
# 4394566173  [Machine Learning in Healthcare and Medicine, ...
# 4396610510  [Impact of Big Data Analytics on Business Perf...
# 4392144307  [Impact of Big Data Analytics on Business Perf...
# 4391092065  [Physical Education and Sports Science, Impact...
# 4391618811  [Physical Education and Sports Science, Impact...
#
#             publication_date  ...  \
# id                            ...
# 4394566173          20240408  ...
# 4396610510          20240430  ...
# 4392144307          20240101  ...
# 4391092065          20240122  ...
# 4391618811          20240207  ...
#
#                                                     subfields  \
# id
# 4394566173  [Health Information Management, Health Informa...
# 4396610510                   [Management Information Systems]
# 4392144307  [Management Information Systems, Computer Netw...
# 4391092065  [Physical Therapy, Sports Therapy and Rehabili...
# 4391618811  [Physical Therapy, Sports Therapy and Rehabili...
#
#                                                       domains  \
# id
# 4394566173                 [Health Sciences, Health Sciences]
# 4396610510                                  [Social Sciences]
# 4392144307  [Social Sciences, Physical Sciences, Physical ...
# 4391092065                 [Health Sciences, Social Sciences]
# 4391618811                 [Health Sciences, Social Sciences]
#
#                                                   affliations  \
# id
# 4394566173                                     [[4210095228]]
# 4396610510         [[226983648], [], [], [], [], [226983648]]
# 4392144307  [[113456305], [99464096], [99464096], [4210139...
# 4391092065                                 [[4210163059], []]
# 4391618811                                 [[4210163059], []]
#
#                                            text_embedding_256  \
# id
# 4394566173  [-0.013616752810776234, 0.030714480206370354, ...
# 4396610510  [-0.08760611712932587, 0.059393979609012604, 0...
# 4392144307  [-0.05282923951745033, 0.06061029061675072, 0....
# 4391092065  [-0.030882054939866066, 0.11646179854869843, 0...
# 4391618811  [-0.030882054939866066, 0.11646179854869843, 0...
#
#                                                     reference  cited_by_year  \
# id
# 4394566173                                                NaN            NaN
# 4396610510  [1964573888, 1986060983, 1987422996, 199627308...           None
# 4392144307                                                NaN            NaN
# 4391092065                                                NaN            NaN
# 4391618811                                                NaN            NaN
#
#            citedby topic_sub_clustering  \
# id
# 4394566173     NaN                  NaN
# 4396610510     NaN                  NaN
# 4392144307     NaN                  NaN
# 4391092065     NaN                  NaN
# 4391618811     NaN                  NaN
#
#                                                       journal journal_if
# id
# 4394566173  EPRA International Journal of Multidisciplinar...   0.454545
# 4396610510  International Journal for Research in Applied ...   0.262504
# 4392144307  Communications in computer and information sci...   0.673717
# 4391092065                                                NaN        NaN
# 4391618811                                                NaN        NaN
#
# [5 rows x 26 columns]

# %%
#例えば、"large language models",'llms','llm'のいずれかの単語を含む、2024年から2024年までの全論文を取得するとき　
papers = get_result(es,'oa_papers',build_es_query_titleabstract_or(["sports analytics",'sports data science','sports performance analysis','machine learning in sports','sports statistics'],2012,2024) )
print(len(papers))
papers.head()
# Out:
# /tmp/ipykernel_1449/1659818795.py:94: DeprecationWarning: Received 'size' via a specific parameter in the presence of a 'body' parameter, which is deprecated and will be removed in a future version. Instead, use only 'body' or only specific parameters.
#   response = es_client.search(index=es_index, body=es_query, scroll=scroll_time, size=batch_size)
# 1004
# 1004
#                                                        fields  \
# id
# 4394624495                 [Neuroscience, Medicine, Medicine]
# 4402247897  [Computer Science, Business, Management and Ac...
# 3047428183  [Medicine, Health Professions, Health Professi...
# 4285544226       [Health Professions, Psychology, Psychology]
# 2971823064  [Computer Science, Computer Science, Computer ...
#
#                                                   affliations  \
# id
# 4394624495  [[141596103], [141596103], [80810150], [141596...
# 4402247897                                               [[]]
# 3047428183                                     [[4210163048]]
# 4285544226                                           [[], []]
# 2971823064               [[98358874], [98358874], [98358874]]
#
#             publication_year  \
# id
# 4394624495              2024
# 4402247897              2024
# 3047428183              2020
# 4285544226              2021
# 2971823064              2019
#
#                                                       domains  \
# id
# 4394624495  [Life Sciences, Health Sciences, Health Sciences]
# 4402247897               [Physical Sciences, Social Sciences]
# 3047428183  [Health Sciences, Health Sciences, Health Scie...
# 4285544226  [Health Sciences, Social Sciences, Social Scie...
# 2971823064  [Physical Sciences, Physical Sciences, Physica...
#
#             publication_date  \
# id
# 4394624495          20240301
# 4402247897          20240830
# 3047428183          20200101
# 4285544226          20210101
# 2971823064          20190906
#
#                                                     subfields  \
# id
# 4394624495  [Cognitive Neuroscience, Orthopedics and Sport...
# 4402247897  [Computer Networks and Communications, Managem...
# 3047428183  [Physiology, Physical Therapy, Sports Therapy ...
# 4285544226  [Physical Therapy, Sports Therapy and Rehabili...
# 2971823064  [Computer Vision and Pattern Recognition, Comp...
#
#                  affliations_list  \
# id
# 4394624495  [80810150, 141596103]
# 4402247897                     []
# 3047428183           [4210163048]
# 4285544226                     []
# 2971823064             [98358874]
#
#                                                         title          id  \
# id
# 4394624495  Is Task Analysis a Contributing Factor to Perf...  4394624495
# 4402247897  Employing Artificial Intelligence Applications...  4402247897
# 3047428183  Study on the Effect of Tennis on the Physical ...  3047428183
# 4285544226  THE PSYCHOLOGICAL CHARACTERISTICS OF YOUNG USE...  4285544226
# 2971823064  Running Event Visualization using Videos from ...  2971823064
#
#            language  ...                                           concepts  \
# id                   ...
# 4394624495       en  ...  [Public health, Factor (programming language),...
# 4402247897       en  ...  [Computer science, Artificial intelligence, En...
# 3047428183       en  ...  [China, Socioeconomics, Environmental health, ...
# 4285544226       en  ...  [CLARITY, Activity tracker, BitTorrent tracker...
# 2971823064       en  ...  [Computer science, Computer vision, Event (par...
#
#                                                        topics  \
# id
# 4394624495  [Computational Principles of Motor Control and...
# 4402247897  [Log Analysis and System Performance Diagnosis...
# 3047428183  [Effects of Physical Activity on Health Outcom...
# 4285544226  [Physical Education and Sports Science Researc...
# 2971823064  [Automatic Video Summarization and Analysis, H...
#
#                                                     doi  \
# id
# 4394624495       https://doi.org/10.2478/pjst-2024-0001
# 4402247897        https://doi.org/10.37575/h/edu/240036
# 3047428183  https://doi.org/10.2991/assehr.k.200727.053
# 4285544226    https://doi.org/10.17721/upj.2021.1(15).8
# 2971823064
#
#                                            text_embedding_256 citedby  \
# id
# 4394624495  [0.06605333834886551, 0.09307071566581726, 0.0...     NaN
# 4402247897  [-2.5489234758424573e-05, 0.012813206762075424...     NaN
# 3047428183  [0.03593587130308151, 0.06506069749593735, 0.0...     NaN
# 4285544226  [0.025173939764499664, 0.1276238113641739, -0....     NaN
# 2971823064  [0.07035969942808151, 0.09912274777889252, 0.0...     NaN
#
#                                                     reference cited_by_year  \
# id
# 4394624495  [1485705743, 1605965041, 1843174427, 197405661...          None
# 4402247897                                                NaN           NaN
# 3047428183                                                NaN           NaN
# 4285544226  [1971209549, 1979183008, 1995204909, 201142629...          None
# 2971823064  [1530232915, 1565050238, 1976382093, 199804286...          None
#
#            topic_sub_clustering  \
# id
# 4394624495                  NaN
# 4402247897                  NaN
# 3047428183                  NaN
# 4285544226                  NaN
# 2971823064                  NaN
#
#                                                       journal journal_if
# id
# 4394624495                Polish Journal of Sport and Tourism   1.061224
# 4402247897  Scientific Journal of King Faisal University H...   0.104478
# 3047428183  Proceedings of the 2019 4th International Conf...   0.000000
# 4285544226                    Ukrainian Psychological Journal   0.139535
# 2971823064                         arXiv (Cornell University)   0.632485
#
# [5 rows x 26 columns]

# %%
reference_pairs = papers.dropna(subset=["reference"]).explode("reference")[["id", "reference"]]
reference_pairs.columns = ["citing_paper_id", "cited_paper_id"]

# 2. in-degree(cited_paper_id ごとに引用された回数）をカウント
in_degree_counts = reference_pairs["cited_paper_id"].value_counts().reset_index()
in_degree_counts.columns = ["referenced_paper_id", "in_degree"]

print(in_degree_counts.head())
# Out:
#    referenced_paper_id  in_degree
# 0           2194775991         30
# 1           1527788842         24
# 2           2064675550         20
# 3           2784056902         18
# 4           2911964244         17

# %%
reference_pairs = papers.dropna(subset=["reference"]).explode("reference")[["id", "reference"]]
reference_pairs.columns = ["citing_paper_id", "referenced_paper_id"]

# 各引用先に対して、引用元のIDをカンマ区切りにして結合
reference_summary = (
    reference_pairs
    .groupby("referenced_paper_id")["citing_paper_id"]
    .apply(lambda ids: ",".join(map(str, sorted(ids.unique())))) 
    .reset_index()
)
reference_summary.columns = ["referenced_paper_id", "in_degree_ids"]

# referenced_paper_id リストからメタデータを取得
ids_to_query = reference_summary["referenced_paper_id"].tolist()
query = build_es_query_by_ids(ids_to_query)
ref_metadata = get_result(es, "oa_papers", query)

ref_metadata = ref_metadata.reset_index(drop=True)

#merge
ref_with_in_degree = ref_metadata.merge(
    reference_summary,
    left_on="id",
    right_on="referenced_paper_id",
    how="left"
)

display(ref_with_in_degree[["id", "title", "cited_by_count", "journal", "in_degree_ids"]].head())

#ref_with_in_degree.to_csv("ref_with_in_degree.csv", index=False, encoding="utf-8")
# Out:
# /tmp/ipykernel_1449/1659818795.py:94: DeprecationWarning: Received 'size' via a specific parameter in the presence of a 'body' parameter, which is deprecated and will be removed in a future version. Instead, use only 'body' or only specific parameters.
#   response = es_client.search(index=es_index, body=es_query, scroll=scroll_time, size=batch_size)
# 12823
#            id                                              title  \
# 0  4285719527                                       Deleted Work
# 1  2962324746  Game-to-Game Prediction of NBA Players’ Points...
# 2  4389749175  A multilayer network framework for soccer anal...
# 3  4390484013  OmniScorer: Real-Time Shot Spot Analysis for C...
# 4  4393870032  Enhancing Skills, Mood, and Performance in Ove...
#
#    cited_by_count                    journal  \
# 0               0                        NaN
# 1               0                        NaN
# 2               0  Chaos Solitons & Fractals
# 3               1                        NaN
# 4               1                   Children
#
#                                        in_degree_ids
# 0  2080234233,2187648190,2493431606,2751600782,29...
# 1                                         4404651385
# 2                                         4404651385
# 3                                         4400352169
# 4                                         4401811174

# %%
def compute_in_degrees_by_generation(papers, es, max_generation=3):
    """
    被引用関係（reference）を n 世代まで再帰的にたどり、
    generation ごとの referenced_paper_id と in_degree_ids を返す。
    """
    from IPython.display import display

    all_generations = []
    visited_ids = set()

    # generation 0 の初期引用ペアを取得
    reference_pairs = papers.dropna(subset=["reference"]).explode("reference")[["id", "reference"]]
    reference_pairs.columns = ["citing_paper_id", "referenced_paper_id"]
    reference_pairs["generation"] = 0

    all_generations.append(reference_pairs.copy())

    current_ids = reference_pairs["referenced_paper_id"].unique().tolist()
    visited_ids.update(current_ids)

    for gen in range(1, max_generation + 1):
        print(f"\n== Generation {gen} ==")

        # 次世代に進む引用先のメタデータ取得
        query = build_es_query_by_ids(current_ids)
        ref_metadata = get_result(es, "oa_papers", query, include_fields=["id", "reference"]).reset_index(drop=True)

        # reference 展開（次の引用先へ）
        next_pairs = ref_metadata.dropna(subset=["reference"]).explode("reference")[["id", "reference"]]
        next_pairs.columns = ["citing_paper_id", "referenced_paper_id"]
        next_pairs = next_pairs[~next_pairs["referenced_paper_id"].isin(visited_ids)]
        next_pairs["generation"] = gen

        if next_pairs.empty:
            print("▶ No further references found.")
            break

        display(next_pairs.head())

        all_generations.append(next_pairs.copy())
        current_ids = next_pairs["referenced_paper_id"].unique().tolist()
        visited_ids.update(current_ids)

    # 各世代の引用ペアから、generation ごとの in_degree 情報を生成
    all_reference_summaries = []

    for df in all_generations:
        reference_summary = (
            df.groupby(["referenced_paper_id", "generation"])["citing_paper_id"]
            .apply(lambda ids: ",".join(map(str, sorted(ids.unique()))))
            .reset_index()
        )
        reference_summary.columns = ["referenced_paper_id", "generation", "in_degree_ids"]
        all_reference_summaries.append(reference_summary)

    return pd.concat(all_reference_summaries, ignore_index=True)

# 関数呼び出し（n世代分）
ref_summary_all = compute_in_degrees_by_generation(papers, es, max_generation=3)

# 結果の表示
from IPython.display import display
display(ref_summary_all.head(10))  # 必要に応じて .head(10) を増やせます
# Out:
# == Generation 1 ==
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 59
#      56     return pd.concat(all_reference_summaries, ignore_index=True)
#      58 # 関数呼び出し（n世代分）
# ---> 59 ref_summary_all = compute_in_degrees_by_generation(papers, es, max_generation=3)
#      61 # 結果の表示
#      62 from IPython.display import display
#
# Cell In[81], line 26, in compute_in_degrees_by_generation(papers, es, max_generation)
#      24 # 次世代に進む引用先のメタデータ取得
#      25 query = build_es_query_by_ids(current_ids)
# ---> 26 ref_metadata = get_result(es, "oa_papers", query, include_fields=["id", "reference"]).reset_index(drop=True)
#      28 # reference 展開（次の引用先へ）
#      29 next_pairs = ref_metadata.dropna(subset=["reference"]).explode("reference")[["id", "reference"]]
#
# TypeError: get_result() got an unexpected keyword argument 'include_fields'

# %%
def get_lightweight_result(es_client, es_index, es_query, scroll_time="2m", batch_size=1000, include_fields=None):
    """
    Get results from Elasticsearch with optional field restriction.
    Lightweight version to avoid transferring unnecessary fields.
    """
    all_hits = []

    # 軽量化：必要なフィールドだけに制限
    if include_fields:
        es_query["_source"] = include_fields

    # 推奨される形で size を body に埋め込む
    es_query["size"] = batch_size

    response = es_client.search(index=es_index, body=es_query, scroll=scroll_time)
    scroll_id = response['_scroll_id']

    while response['hits']['hits']:
        all_hits.extend(hit['_source'] for hit in response['hits']['hits'])
        response = es_client.scroll(scroll_id=scroll_id, scroll=scroll_time)

    es_client.clear_scroll(scroll_id=scroll_id)
    return pd.DataFrame(all_hits)

# %%
def compute_in_degrees_by_generation(papers, es, max_generation=3):
    """
    被引用関係（reference）を n 世代まで再帰的にたどり、
    generation ごとの referenced_paper_id と in_degree_ids を返す。
    """
    from IPython.display import display

    all_generations = []
    visited_ids = set()

    # generation 0 の初期引用ペアを取得
    reference_pairs = papers.dropna(subset=["reference"]).explode("reference")[["id", "reference"]]
    reference_pairs.columns = ["citing_paper_id", "referenced_paper_id"]
    reference_pairs["generation"] = 0

    all_generations.append(reference_pairs.copy())

    current_ids = reference_pairs["referenced_paper_id"].unique().tolist()
    visited_ids.update(current_ids)

    for gen in range(1, max_generation + 1):
        print(f"\n== Generation {gen} ==")

        # 次世代に進む引用先のメタデータ取得（軽量化版）
        query = build_es_query_by_ids(current_ids)
        ref_metadata = get_lightweight_result(es, "oa_papers", query, include_fields=["id", "reference"]).reset_index(drop=True)

        # reference 展開（次の引用先へ）
        next_pairs = ref_metadata.dropna(subset=["reference"]).explode("reference")[["id", "reference"]]
        next_pairs.columns = ["citing_paper_id", "referenced_paper_id"]
        next_pairs = next_pairs[~next_pairs["referenced_paper_id"].isin(visited_ids)]
        next_pairs["generation"] = gen

        if next_pairs.empty:
            print("No further references found.")
            break

        display(next_pairs.head())

        all_generations.append(next_pairs.copy())
        current_ids = next_pairs["referenced_paper_id"].unique().tolist()
        visited_ids.update(current_ids)

    # 各世代の引用ペアから、generation ごとの in_degree 情報を生成
    all_reference_summaries = []

    for df in all_generations:
        reference_summary = (
            df.groupby(["referenced_paper_id", "generation"])["citing_paper_id"]
            .apply(lambda ids: ",".join(map(str, sorted(ids.unique()))))
            .reset_index()
        )
        reference_summary.columns = ["referenced_paper_id", "generation", "in_degree_ids"]
        all_reference_summaries.append(reference_summary)

    return pd.concat(all_reference_summaries, ignore_index=True)


# 実行：3世代まで引用関係をたどる
ref_summary_all = compute_in_degrees_by_generation(papers, es, max_generation=3)

# 結果を表示
from IPython.display import display
display(ref_summary_all.head(10))
# Out:
# == Generation 1 ==
#    citing_paper_id referenced_paper_id  generation
# 0       2897736987          1965637139           1
# 0       2897736987          2024605342           1
# 0       2897736987          2084583116           1
# 0       2897736987          2135058044           1
# 0       2897736987          2580107250           1
# == Generation 2 ==
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[85], line 60
#      56     return pd.concat(all_reference_summaries, ignore_index=True)
#      59 # ✅ 実行：3世代まで引用関係をたどる
# ---> 60 ref_summary_all = compute_in_degrees_by_generation(papers, es, max_generation=3)
#      62 # ✅ 結果を表示
#      63 from IPython.display import display
#
# Cell In[85], line 26, in compute_in_degrees_by_generation(papers, es, max_generation)
#      24 # 次世代に進む引用先のメタデータ取得（軽量化版）
#      25 query = build_es_query_by_ids(current_ids)
# ---> 26 ref_metadata = get_lightweight_result(es, "oa_papers", query, include_fields=["id", "reference"]).reset_index(drop=True)
#      28 # reference 展開（次の引用先へ）
#      29 next_pairs = ref_metadata.dropna(subset=["reference"]).explode("reference")[["id", "reference"]]
#
# Cell In[84], line 15, in get_lightweight_result(es_client, es_index, es_query, scroll_time, batch_size, include_fields)
#      12 # 推奨される形で size を body に埋め込む
#      13 es_query["size"] = batch_size
# ---> 15 response = es_client.search(index=es_index, body=es_query, scroll=scroll_time)
#      16 scroll_id = response['_scroll_id']
#      18 while response['hits']['hits']:
#
# File /usr/local/lib/python3.12/site-packages/elasticsearch/_sync/client/utils.py:455, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     452         except KeyError:
#     453             pass
# --> 455 return api(*args, **kwargs)
#
# File /usr/local/lib/python3.12/site-packages/elasticsearch/_sync/client/__init__.py:4255, in Elasticsearch.search(self, index, aggregations, aggs, allow_no_indices, allow_partial_search_results, analyze_wildcard, analyzer, batched_reduce_size, ccs_minimize_roundtrips, collapse, default_operator, df, docvalue_fields, error_trace, expand_wildcards, explain, ext, fields, filter_path, force_synthetic_source, from_, highlight, human, ignore_throttled, ignore_unavailable, include_named_queries_score, indices_boost, knn, lenient, max_concurrent_shard_requests, min_compatible_shard_node, min_score, pit, post_filter, pre_filter_shard_size, preference, pretty, profile, q, query, rank, request_cache, rescore, rest_total_hits_as_int, retriever, routing, runtime_mappings, script_fields, scroll, search_after, search_type, seq_no_primary_term, size, slice, sort, source, source_excludes, source_includes, stats, stored_fields, suggest, suggest_field, suggest_mode, suggest_size, suggest_text, terminate_after, timeout, track_scores, track_total_hits, typed_keys, version, body)
#    4253 if __body is not None:
#    4254     __headers["content-type"] = "application/json"
# -> 4255 return self.perform_request(  # type: ignore[return-value]
#    4256     "POST",
#    4257     __path,
#    4258     params=__query,
#    4259     headers=__headers,
#    4260     body=__body,
#    4261     endpoint_id="search",
#    4262     path_parts=__path_parts,
#    4263 )
#
# File /usr/local/lib/python3.12/site-packages/elasticsearch/_sync/client/_base.py:271, in BaseClient.perform_request(self, method, path, params, headers, body, endpoint_id, path_parts)
#     255 def perform_request(
#     256     self,
#     257     method: str,
#    (...)    264     path_parts: Optional[Mapping[str, Any]] = None,
#     265 ) -> ApiResponse[Any]:
#     266     with self._otel.span(
#     267         method,
#     268         endpoint_id=endpoint_id,
#     269         path_parts=path_parts or {},
#     270     ) as otel_span:
# --> 271         response = self._perform_request(
#     272             method,
#     273             path,
#     274             params=params,
#     275             headers=headers,
#     276             body=body,
#     277             otel_span=otel_span,
#     278         )
#     279         otel_span.set_elastic_cloud_metadata(response.meta.headers)
#     280         return response
#
# File /usr/local/lib/python3.12/site-packages/elasticsearch/_sync/client/_base.py:352, in BaseClient._perform_request(self, method, path, params, headers, body, otel_span)
#     349         except (ValueError, KeyError, TypeError):
#     350             pass
# --> 352     raise HTTP_EXCEPTIONS.get(meta.status, ApiError)(
#     353         message=message, meta=meta, body=resp_body
#     354     )
#     356 # 'X-Elastic-Product: Elasticsearch' should be on every 2XX response.
#     357 if not self._verified_elasticsearch:
#     358     # If the header is set we mark the server as verified.
#
# BadRequestError: BadRequestError(400, 'search_phase_execution_exception', 'failed to create query: The number of terms [300737] used in the Terms Query request has exceeded the allowed maximum of [65536]. This maximum can be set by changing the [index.max_terms_count] index level setting.')
